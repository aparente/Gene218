# %% [markdown]
# # -find vs. rfind
#      - find searches from beginning of string
#      -rfind searches from end of string
#      -both only give you first occurence of whatever you’re searching for

# %% [markdown]
# # Problem 1

# %%
A = ['hey', 'I', 'just', 'met', 'you']
B = ['and', 'this', 'is', 'crazy']
C = A
print A
return A
print B
return B
print C
return C
A.extend(B)
C.extend(['but', "here's", 'my', 'number']
print A
# Out:
#   File "<ipython-input-2-6b943af390ae>", line 12
#     print A
#         ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# ColiDH1.fa.webloc     VSG_Module/           myDogsRNA.txt.webloc
# Untitled0.ipynb       mature.fa.webloc

# %% [markdown]
# # Why didn't this work?
# Shallow copy vs. Deep copy
#      - deep copy: copy data over to new location
#      - shallow copy: creating reference to old data in new variable

# %%
mrna_name=[]
mrna_seq=[]
mature=open('mature.fa.webloc', mode='rU')

# %%
return mature
# Out:
#   File "<ipython-input-6-96ab843a4f72>", line 1
#     return mature
# SyntaxError: 'return' outside function

# %%
mature = open('mature.fa', mode='rU')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-36167409bf8c> in <module>()
# ----> 1 mature = open('mature.fa', mode='rU')
#
# IOError: [Errno 2] No such file or directory: 'mature.fa'

# %%
ls
# Out:
# ColiDH1.fa.webloc     VSG_Module/           myDogsRNA.txt.webloc
# Untitled0.ipynb       mature.fa.webloc

# %%
pwd
# Out:
# u'/Users/Angelica/Box Sync/Gene218'

# %%
ls
# Out:
# ColiDH1.fa.webloc     VSG_Module/           myDogsRNA.txt.webloc
# Untitled0.ipynb       mature.fa.webloc

# %%
ls
# Out:
# ColiDH1.fa.webloc     VSG_Module/           myDogsRNA.txt
# Untitled0.ipynb       mature.fa.webloc      myDogsRNA.txt.webloc

# %%
mrna_name=[]
mrna_seq=[]
mature=open('mature.fa.webloc', mode='rU')

# %%
return mature
# Out:
#   File "<ipython-input-15-96ab843a4f72>", line 1
#     return mature
# SyntaxError: 'return' outside function

# %%
#i is the line number of mature.fa
x=0
for i in mature:
    if i[0]=='>'
        mrna_name.append(i) 
    else:
        mrna_seq.append(i)
        
print mrna_seq
return mrna_seq
print mrna_name
return mrna_name
# Out:
#   File "<ipython-input-32-399f30bf1b4a>", line 4
#     if i[0]='A'
#            ^
# SyntaxError: invalid syntax

# %%
for i in mature:
    print i
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <!DOCTYPE plist PUBLIC "-//Apple//DTD PLIST 1.0//EN" "http://www.apple.com/DTDs/PropertyList-1.0.dtd">
#
# <plist version="1.0">
#
# <dict>
#
# 	<key>URL</key>
#
# 	<string>https://d1b10bmlvqabco.cloudfront.net/attach/hwuvlt3cf8l5or/h3f9wwwcaoe6tr/hx6glja7u2kr/mature.fa</string>
#
# </dict>
#
# </plist>

# %% [raw]
# ls

# %%
more mature.fa

# %%
mature=open('mature.fa', mode='rU')
for i in mature:
    if i[0]=='>':
        mrna_name.append(i) 
    else:
        mrna_seq.append(i)

# %%
mrna_real=[]
mydogsrna=open('myDogsRNAconverted.txt', mode='rU')
linker='UCGU'
rna_dict={mrna_name:mrna_seq}
for i in mydogsrna:
    if linker in i:
        n=i.rfind(linker)
        real=i[0:n]
        mrna_real.append(real)
        
    else:
        mrna_real = mrna_real
print mrna_real
# Out:
# ['UGAGGUAGUAGAUUGUAUAGU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGGUUGUGUGGU', 'UGAGGUAGUAGGUUGUAUAGU', 'UGAGGUAGUAGGUUGUAUAGU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUCUAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGUUUGUACAGUU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGU', 'UGAGGUAGUAGAUUGUAUAGU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UUCUACAGUCCGACGAUC', 'UGAGGUAGUAGGUUGUAUAGUU', 'CAACCGUUACCAUUACUGAGUU', 'UGAGGUAGUAGAUUGUAUAGU', 'UAGCACCAUCUGACAUCGGUUA', 'UGAGGUAGUAGAUUGUAUAGUUUUGUUUC', 'UCGUUUCCGGCUCGUUGGAGCU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGGUUGUAUAGUU', 'UCGAAACCGGGCGGAAACACCA', 'UGAGGUAGUAGAUUGUAUAGU', 'UGAGGUAGUAGGUUGUGUGGU', 'UGAGGUAGUAGAUUGUAUAGU', 'UGAGGUAGUAGGUUGUAUAGU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGGGGUGGGUUGGAUAUUU', 'UGAGGUAGUAGAUUGUAUAGU', 'UACAGUAUAGAUGAUGUACU', 'UGAGGUAGUAGAUUGUAUAGUU', 'UGAGGCAGUAGAUUGUAUAGUU', 'UAUUGCACUUGUCCCGGCCUGU', 'UGAGAUCGUUCAGUACGGCAA', 'UGAGGUAGUAGUUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUAGUUUCGUAUG', 'CAUUGGUCAUCUC', 'UGUGGUAGUAGAUUGUAUAGUU', 'UGAGGUAGUAGAUUGUAUCGUUUCGUCUG', 'UGAGGUAGUGGAUUGUAUAGU', 'UGAGGUAGUAGGUUGU